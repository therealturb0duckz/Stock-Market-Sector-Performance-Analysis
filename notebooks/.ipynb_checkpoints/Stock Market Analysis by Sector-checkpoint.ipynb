# %% [markdown]
# # Stock Market Analysis by Sector

# %% [markdown]
# ### Brief Information :
#     The project mainly analyzes the performance of various industry sectors to support sustainable investment decisions.
#     we use Exploratory Data Analysis (EDA) to visualize and summarize stock market data to uncover patterns,
#     trends, and correlations. Key analyses include sector performance during COVID-19, risk-adjusted returns, and
#     correlation behaviors between sectors. The project aim to answer the author curiosity in
#     identifying promising and stable sectors for long-term sustainable investing. (and also for data science class :) )

# %% [markdown]
# ### Tools & Techniques :
#     Python (pandas, matplotlib, seaborn)

# %% [markdown]
# ### EDA Techniques :
#     - Summary statistics (mean, median, std dev)
#     - Time series plotting
#     - Sector-wise distribution analysis
#     - Correlation heatmaps
#     - Outlier detection using box plots
#     - Trend analysis

# %% [markdown]
# ### Objectives :
#     - Analyze correlations between industry sectors’ stock returns
#     - Evaluate sector performance during key COVID-19 periods
#     - Assess sectors’ risk-adjusted returns over 5 years

# %% [markdown]
# ### Research Questions :
#     1) Which industry sectors exhibit the strongest correlations in their stock price returns?
#     2) How did different sectors perform during key COVID-19 periods (pre-pandemic, pandemic onset, and recovery)?
#     3) Which industry sectors offer the best risk-adjusted returns over 5 years

# %% [markdown]
# ### Inferential Methods by Research Question
#
# | #  | Research Question                                                                                           | Test                 | Reason                                                                                  |
# | -- | ----------------------------------------------------------------------------------------------------------- | -------------------- | -------------------------------------------------------------------------------------------- |
# | Q1 | Which industry sectors exhibit the strongest correlations in their stock price returns?                     | Spearman correlation | Assess strength and direction of monotonic relationships between sector return pairs         |
# | Q2 | How did different sectors perform during key COVID-19 periods (pre-pandemic, pandemic onset, and recovery)? | Kruskal-Wallis test  | Compare sector returns across different COVID-19 periods (non-parametric test for 3+ groups) |
# | Q3 | Which industry sectors offer the best risk-adjusted returns over 5 years                                    | Kruskal-Wallis test  | Compare Sharpe ratios across sectors to identify differences in risk-adjusted performance    |

# %% [markdown]
# ### Dataset :
# https://github.com/datasets/s-and-p-500-companies <br>
# https://www.kaggle.com/datasets/iveeaten3223times/massive-yahoo-finance-dataset/dataLinks

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway
import numpy as np

# %%
# import first dataset
df_5_yrs = pd.read_csv("../data/stock_details_5_years.csv")
df_5_yrs
# Out:
#                              Date        Open        High         Low  \
# 0       2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594
# 1       2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595
# 2       2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998
# 3       2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# ...                           ...         ...         ...         ...
# 602957  2023-11-29 00:00:00-05:00   26.360001   26.397499   26.120001
# 602958  2023-11-29 00:00:00-05:00   27.680000   28.535000   27.680000
# 602959  2023-11-29 00:00:00-05:00   75.940002   76.555000   75.257500
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
# 602961  2023-11-29 00:00:00-05:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company
# 0        43.083508  167080000       0.00           0.0    AAPL
# 1       104.636131   28123200       0.00           0.0    MSFT
# 2        54.729000   31004000       0.00           0.0   GOOGL
# 3        83.678497  132264000       0.00           0.0    AMZN
# 4        39.037853   54917200       0.04           0.0    NVDA
# ...            ...        ...        ...           ...     ...
# 602957   26.150000    1729147       0.00           0.0     PPL
# 602958   28.350000    1940066       0.00           0.0    FITB
# 602959   75.610001     298699       0.00           0.0     IFF
# 602960   44.209999    2217579       0.00           0.0     CCJ
# 602961   83.889999     830092       0.00           0.0     LYV
#
# [602962 rows x 9 columns]

# %%
# 1 import additional sectors and industries data
url = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv"
df_sec_ind = pd.read_csv(url)
df_sec_ind
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# 2                           Health Care Equipment  North Chicago, Illinois
# 3                                   Biotechnology  North Chicago, Illinois
# 4                  IT Consulting & Other Services          Dublin, Ireland
# ..                                            ...                      ...
# 498  Industrial Machinery & Supplies & Components   White Plains, New York
# 499                                   Restaurants     Louisville, Kentucky
# 500            Electronic Equipment & Instruments   Lincolnshire, Illinois
# 501                         Health Care Equipment          Warsaw, Indiana
# 502                               Pharmaceuticals   Parsippany, New Jersey
#
#      Date added      CIK      Founded
# 0    1957-03-04    66740         1902
# 1    2017-07-26    91142         1916
# 2    1957-03-04     1800         1888
# 3    2012-12-31  1551152  2013 (1888)
# 4    2011-07-06  1467373         1989
# ..          ...      ...          ...
# 498  2011-11-01  1524472         2011
# 499  1997-10-06  1041061         1997
# 500  2019-12-23   877212         1969
# 501  2001-08-07  1136869         1927
# 502  2013-06-21  1555280         1952
#
# [503 rows x 8 columns]

# %%
#2 merging data set and changing the column header for better understanding 
df_sec_ind_renamed = df_sec_ind.rename(columns={
    'Symbol': 'Company',
    'GICS Sector': 'Sector',
    'GICS Sub-Industry': 'Industry'
})

merged_df = df_5_yrs.merge(df_sec_ind_renamed[['Company', 'Sector', 'Industry']], on='Company', how='left')
merged_df
# Out:
#                              Date        Open        High         Low  \
# 0       2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594
# 1       2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595
# 2       2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998
# 3       2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# ...                           ...         ...         ...         ...
# 602957  2023-11-29 00:00:00-05:00   26.360001   26.397499   26.120001
# 602958  2023-11-29 00:00:00-05:00   27.680000   28.535000   27.680000
# 602959  2023-11-29 00:00:00-05:00   75.940002   76.555000   75.257500
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
# 602961  2023-11-29 00:00:00-05:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company  \
# 0        43.083508  167080000       0.00           0.0    AAPL
# 1       104.636131   28123200       0.00           0.0    MSFT
# 2        54.729000   31004000       0.00           0.0   GOOGL
# 3        83.678497  132264000       0.00           0.0    AMZN
# 4        39.037853   54917200       0.04           0.0    NVDA
# ...            ...        ...        ...           ...     ...
# 602957   26.150000    1729147       0.00           0.0     PPL
# 602958   28.350000    1940066       0.00           0.0    FITB
# 602959   75.610001     298699       0.00           0.0     IFF
# 602960   44.209999    2217579       0.00           0.0     CCJ
# 602961   83.889999     830092       0.00           0.0     LYV
#
#                         Sector                                    Industry
# 0       Information Technology  Technology Hardware, Storage & Peripherals
# 1       Information Technology                            Systems Software
# 2       Communication Services                Interactive Media & Services
# 3       Consumer Discretionary                            Broadline Retail
# 4       Information Technology                              Semiconductors
# ...                        ...                                         ...
# 602957               Utilities                          Electric Utilities
# 602958              Financials                              Regional Banks
# 602959               Materials                         Specialty Chemicals
# 602960                     NaN                                         NaN
# 602961  Communication Services                      Movies & Entertainment
#
# [602962 rows x 11 columns]

# %%
# test some values
merged_df[merged_df['Company'] == 'NVDA']
# result : as we wanted, Sector and Industry columns are filled with value.
# Out:
#                              Date        Open        High         Low  \
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# 462     2018-11-30 00:00:00-05:00   39.134605   40.650374   38.631003
# 920     2018-12-03 00:00:00-05:00   42.818602   43.334604   41.513699
# 1378    2018-12-04 00:00:00-05:00   41.736964   41.786580   38.824505
# 1836    2018-12-06 00:00:00-05:00   37.569232   39.318197   37.412940
# ...                           ...         ...         ...         ...
# 600511  2023-11-22 00:00:00-05:00  498.519989  503.350006  476.899994
# 601002  2023-11-24 00:00:00-05:00  484.700012  489.209991  477.450012
# 601493  2023-11-27 00:00:00-05:00  478.000000  485.299988  476.519989
# 601984  2023-11-28 00:00:00-05:00  482.359985  483.230011  474.730011
# 602475  2023-11-29 00:00:00-05:00  483.790009  487.619904  478.635406
#
#              Close    Volume  Dividends  Stock Splits Company  \
# 4        39.037853  54917200       0.04           0.0    NVDA
# 462      40.543697  72956400       0.00           0.0    NVDA
# 920      42.183514  89080400       0.00           0.0    NVDA
# 1378     38.975834  81211200       0.00           0.0    NVDA
# 1836     39.268578  69230800       0.00           0.0    NVDA
# ...            ...       ...        ...           ...     ...
# 600511  487.160004  89942000       0.00           0.0    NVDA
# 601002  477.760010  29464500       0.00           0.0    NVDA
# 601493  482.420013  39566200       0.00           0.0    NVDA
# 601984  478.209991  40089000       0.00           0.0    NVDA
# 602475  480.734985  20498046       0.00           0.0    NVDA
#
#                         Sector        Industry
# 4       Information Technology  Semiconductors
# 462     Information Technology  Semiconductors
# 920     Information Technology  Semiconductors
# 1378    Information Technology  Semiconductors
# 1836    Information Technology  Semiconductors
# ...                        ...             ...
# 600511  Information Technology  Semiconductors
# 601002  Information Technology  Semiconductors
# 601493  Information Technology  Semiconductors
# 601984  Information Technology  Semiconductors
# 602475  Information Technology  Semiconductors
#
# [1258 rows x 11 columns]

# %% [markdown]
# ### Data Observation

# %%
# 1
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602962 entries, 0 to 602961
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          602962 non-null  object
#  1   Open          602962 non-null  float64
#  2   High          602962 non-null  float64
#  3   Low           602962 non-null  float64
#  4   Close         602962 non-null  float64
#  5   Volume        602962 non-null  int64
#  6   Dividends     602962 non-null  float64
#  7   Stock Splits  602962 non-null  float64
#  8   Company       602962 non-null  object
#  9   Sector        413881 non-null  object
#  10  Industry      413881 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 50.6+ MB

# %%
merged_df[merged_df['Stock Splits'] != 0]
# Out:
#                              Date        Open        High         Low  \
# 3661    2018-12-11 00:00:00-05:00   24.464137   24.464137   23.767314
# 8909    2018-12-28 00:00:00-05:00   22.098485   22.338686   21.507592
# 21394   2019-02-07 00:00:00-05:00   64.349998   64.889999   63.040001
# 26708   2019-02-26 00:00:00-05:00   66.123135   66.797230   64.529804
# 37982   2019-04-01 00:00:00-04:00    7.509056    7.621611    7.428659
# ...                           ...         ...         ...         ...
# 548691  2023-06-23 00:00:00-04:00  130.053322  133.120520  129.219508
# 568830  2023-08-22 00:00:00-04:00   43.330002   44.090000   43.230000
# 568838  2023-08-22 00:00:00-04:00   70.648486   70.936079   69.924551
# 578424  2023-09-20 00:00:00-04:00   94.699997   96.419998   93.540001
# 582393  2023-10-02 00:00:00-04:00  218.749616  221.386356  208.702038
#
#              Close    Volume  Dividends  Stock Splits Company  \
# 3661     23.999590   1495050      0.000         1.500     ROL
# 8909     21.824656   8881065      0.000         1.806    DELL
# 21394    63.910000   2904700      0.000         2.000     CNC
# 26708    65.326469  16651495      0.000         1.040      GE
# 37982     7.444739  16624300      0.000         1.200     BBD
# ...            ...       ...        ...           ...     ...
# 548691  132.614288    356400      4.845         0.963     TRI
# 568830   43.790001   3608500      0.000         2.000    CPRT
# 568838   70.707993   2517000      0.000         2.000     SRE
# 578424   94.730003   6124500      0.000         2.000     NVO
# 582393  213.476135   6387700      0.000         1.128     DHR
#
#                         Sector                                    Industry
# 3661               Industrials         Environmental & Facilities Services
# 8909    Information Technology  Technology Hardware, Storage & Peripherals
# 21394              Health Care                         Managed Health Care
# 26708              Industrials                         Aerospace & Defense
# 37982                      NaN                                         NaN
# ...                        ...                                         ...
# 548691                     NaN                                         NaN
# 568830             Industrials                Diversified Support Services
# 568838               Utilities                             Multi-Utilities
# 578424                     NaN                                         NaN
# 582393             Health Care              Life Sciences Tools & Services
#
# [71 rows x 11 columns]

# %%
merged_df[merged_df['Dividends'] != 0]
# Out:
#                              Date        Open        High         Low  \
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# 27      2018-11-29 00:00:00-05:00   42.493415   42.622759   42.226108
# 69      2018-11-29 00:00:00-05:00  135.975210  136.696170  134.947826
# 81      2018-11-29 00:00:00-05:00   39.549692   39.647964   39.056101
# 93      2018-11-29 00:00:00-05:00  175.483302  176.763477  172.922939
# ...                           ...         ...         ...         ...
# 601560  2023-11-27 00:00:00-05:00  412.410004  414.010010  410.390015
# 601807  2023-11-27 00:00:00-05:00  127.550003  128.410004  127.220001
# 601930  2023-11-27 00:00:00-05:00   47.799999   47.910000   47.090000
# 602280  2023-11-28 00:00:00-05:00  136.729996  137.289993  136.250000
# 602348  2023-11-28 00:00:00-05:00   50.509998   50.740002   50.330002
#
#              Close    Volume  Dividends  Stock Splits Company  \
# 4        39.037853  54917200     0.0400           0.0    NVDA
# 27       42.234730  11564300     0.3900           0.0      KO
# 69      135.614716   2970200     0.8000           0.0     UNP
# 81       39.558624   6867200     0.2775           0.0     NEE
# 93      174.435883   2665700     0.8000           0.0      GS
# ...            ...       ...        ...           ...     ...
# 601560  412.250000   1326900     0.9000           0.0    SPGI
# 601807  127.690002   1143800     0.6050           0.0     YUM
# 601930   47.630001   1399800     0.1500           0.0     WPM
# 602280  136.380005   1404000     0.1900           0.0      EA
# 602348   50.480000   3183900     0.5730           0.0     SLF
#
#                         Sector                               Industry
# 4       Information Technology                         Semiconductors
# 27            Consumer Staples  Soft Drinks & Non-alcoholic Beverages
# 69                 Industrials                    Rail Transportation
# 81                   Utilities                        Multi-Utilities
# 93                  Financials         Investment Banking & Brokerage
# ...                        ...                                    ...
# 601560              Financials             Financial Exchanges & Data
# 601807  Consumer Discretionary                            Restaurants
# 601930                     NaN                                    NaN
# 602280  Communication Services         Interactive Home Entertainment
# 602348                     NaN                                    NaN
#
# [6857 rows x 11 columns]

# %%
# check s&p500 companies information
print(merged_df['Company'].nunique())  
# result : understanding because some companies might have multiple share classes (?)
# Out:
# 491

# %%
# count unique Industry and Sector
merged_df['Industry'].nunique()
# Out:
# 110

# %%
merged_df['Sector'].nunique()
# Out:
# 11

# %%
# count how many companies in each sector 
merged_df.groupby('Sector')['Company'].nunique()
# Out:
# Sector
# Communication Services    14
# Consumer Discretionary    31
# Consumer Staples          24
# Energy                    17
# Financials                51
# Health Care               43
# Industrials               52
# Information Technology    48
# Materials                 15
# Real Estate               18
# Utilities                 21
# Name: Company, dtype: int64

# %%
# check if there are NaN values in sector and industry that might not be merged
nan_rows = merged_df[merged_df[['Company', 'Sector', 'Industry']].isna().any(axis=1)]
nan_rows
# Out:
#                              Date        Open        High         Low  \
# 9       2018-11-29 00:00:00-05:00   33.520714   33.891693   33.450050
# 12      2018-11-29 00:00:00-05:00   19.554069   19.699040   19.460263
# 22      2018-11-29 00:00:00-05:00  163.608448  164.291218  162.119641
# 25      2018-11-29 00:00:00-05:00  121.519997  122.320000  121.379997
# 31      2018-11-29 00:00:00-05:00   77.506613   79.218716   75.676750
# ...                           ...         ...         ...         ...
# 602947  2023-11-29 00:00:00-05:00   33.720001   33.790001   33.544998
# 602948  2023-11-29 00:00:00-05:00    3.555000    3.580000    3.550000
# 602951  2023-11-29 00:00:00-05:00   40.590000   40.610001   39.939999
# 602952  2023-11-29 00:00:00-05:00   15.850000   16.010000   15.690900
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
#
#              Close   Volume  Dividends  Stock Splits Company Sector Industry
# 9        33.503048  7056600        0.0           0.0     TSM    NaN      NaN
# 12       19.579651  2778200        0.0           0.0     NVO    NaN      NaN
# 22      162.650681  1079700        0.0           0.0    ASML    NaN      NaN
# 25      121.779999   125600        0.0           0.0      TM    NaN      NaN
# 31       79.010368   661400        0.0           0.0     FMX    NaN      NaN
# ...            ...      ...        ...           ...     ...    ...      ...
# 602947   33.700001   668408        0.0           0.0      TS    NaN      NaN
# 602948    3.580000  5158521        0.0           0.0     NOK    NaN      NaN
# 602951   39.980000   414526        0.0           0.0     FTS    NaN      NaN
# 602952   15.855000  2381943        0.0           0.0    BEKE    NaN      NaN
# 602960   44.209999  2217579        0.0           0.0     CCJ    NaN      NaN
#
# [189081 rows x 11 columns]

# %%
nan_rows['Company'].nunique() 
# we need to fill in 157 companies
# Out:
# 157

# %%
157+334
# Out:
# 491

# %%
nan_rows['Company'].dropna().unique()
# Out:
# array(['TSM', 'NVO', 'ASML', 'TM', 'FMX', 'SHEL', 'NVS', 'AZN', 'BABA',
#        'PDD', 'SAP', 'TTE', 'BHP', 'HDB', 'HSBC', 'BUD', 'RY', 'UL',
#        'SNY', 'RIO', 'TD', 'SONY', 'MUFG', 'BP', 'PBR', 'SHOP', 'EQNR',
#        'UBS', 'MELI', 'IBN', 'DEO', 'CNI', 'ENB', 'NTES', 'INFY', 'RELX',
#        'GSK', 'CNQ', 'BTI', 'RACE', 'STLA', 'CP', 'SAN', 'SMFG', 'VALE',
#        'TRI', 'ITUB', 'BN', 'BMO', 'EPD', 'BBVA', 'SCCO', 'PXD', 'E',
#        'BNS', 'TEAM', 'HMC', 'MRVL', 'NGG', 'ING', 'BSBR', 'ET', 'HES',
#        'CRH', 'TAK', 'MFG', 'ABEV', 'LNG', 'JD', 'STM', 'SU', 'BIDU',
#        'SGEN', 'SQ', 'WDS', 'TRP', 'MPLX', 'CM', 'BCE', 'BBD', 'SPOT',
#        'MFC', 'LYG', 'FERG', 'WCN', 'ARES', 'CVE', 'ORAN', 'IMO', 'IBKR',
#        'QSR', 'GOLD', 'PUK', 'ZS', 'MDB', 'CHT', 'SLF', 'CQP', 'PKX',
#        'ELP', 'VEEV', 'NTR', 'CCEP', 'BCS', 'RYAAY', 'AEM', 'EC', 'ARGX',
#        'ANSS', 'TU', 'SPLK', 'WIT', 'DB', 'HUBS', 'VOD', 'TEF', 'TLK',
#        'NWG', 'GIB', 'DFS', 'TCOM', 'RCI', 'WPM', 'FNV', 'ICLR', 'SE',
#        'SNAP', 'IX', 'FCNCA', 'MT', 'HEI', 'GMAB', 'ALNY', 'BGNE', 'UMC',
#        'TS', 'NOK', 'FTS', 'CCJ', 'PDX', 'TW', 'ALC', 'PINS', 'ZM', 'NET',
#        'BNTX', 'LI', 'BEKE', 'SNOW', 'SYM', 'RBLX', 'CPNG', 'GFS', 'NU',
#        'HLN', 'MBLY', 'ARM'], dtype=object)

# %%
# map the company ticker to their sector
company_sector_map = {
    'TSM': 'Information Technology',
    'NVO': 'Health Care',
    'ASML': 'Information Technology',
    'TM': 'Consumer Discretionary',
    'FMX': 'Consumer Staples',
    'SHEL': 'Energy',
    'NVS': 'Health Care',
    'AZN': 'Health Care',
    'BABA': 'Consumer Discretionary',
    'PDD': 'Consumer Discretionary',
    'SAP': 'Information Technology',
    'TTE': 'Energy',
    'BHP': 'Materials',
    'HDB': 'Financials',
    'HSBC': 'Financials',
    'BUD': 'Consumer Staples',
    'RY': 'Financials',
    'UL': 'Consumer Staples',
    'SNY': 'Health Care',
    'RIO': 'Materials',
    'TD': 'Financials',
    'SONY': 'Consumer Discretionary',
    'MUFG': 'Financials',
    'BP': 'Energy',
    'PBR': 'Energy',
    'SHOP': 'Information Technology',
    'EQNR': 'Energy',
    'UBS': 'Financials',
    'MELI': 'Consumer Discretionary',
    'IBN': 'Financials',
    'DEO': 'Consumer Staples',
    'CNI': 'Industrials',
    'ENB': 'Energy',
    'NTES': 'Communication Services',
    'INFY': 'Information Technology',
    'RELX': 'Industrials',
    'GSK': 'Health Care',
    'CNQ': 'Energy',
    'BTI': 'Consumer Staples',
    'RACE': 'Consumer Discretionary',
    'STLA': 'Consumer Discretionary',
    'CP': 'Industrials',
    'SAN': 'Financials',
    'SMFG': 'Financials',
    'VALE': 'Materials',
    'TRI': 'Industrials',
    'ITUB': 'Financials',
    'BN': 'Financials',
    'BMO': 'Financials',
    'EPD': 'Energy',
    'BBVA': 'Financials',
    'SCCO': 'Materials',
    'PXD': 'Energy',
    'E': 'Energy',
    'BNS': 'Financials',
    'TEAM': 'Information Technology',
    'HMC': 'Consumer Discretionary',
    'MRVL': 'Information Technology',
    'NGG': 'Utilities',
    'ING': 'Financials',
    'BSBR': 'Financials',
    'ET': 'Energy',
    'CRH': 'Materials',
    'TAK': 'Health Care',
    'MFG': 'Financials',
    'ABEV': 'Consumer Staples',
    'LNG': 'Energy',
    'JD': 'Consumer Discretionary',
    'STM': 'Information Technology',
    'SU': 'Energy',
    'BIDU': 'Communication Services',
    'SGEN': 'Health Care',
    'SQ': 'Information Technology',
    'WDS': 'Energy',
    'TRP': 'Energy',
    'MPLX': 'Energy',
    'CM': 'Financials',
    'BCE': 'Communication Services',
    'BBD': 'Industrials',
    'SPOT': 'Communication Services',
    'MFC': 'Financials',
    'LYG': 'Financials',
    'TTD': 'Information Technology',
    'FERG': 'Industrials',
    'WCN': 'Industrials',
    'ARES': 'Financials',
    'CVE': 'Energy',
    'ORAN': 'Communication Services',
    'IMO': 'Energy',
    'IBKR': 'Financials',
    'QSR': 'Consumer Discretionary',
    'GOLD': 'Materials',
    'PUK': 'Financials',
    'ZS': 'Information Technology',
    'MDB': 'Information Technology',
    'CHT': 'Communication Services',
    'SLF': 'Financials',
    'CQP': 'Energy',
    'PKX': 'Materials',
    'ELP': 'Utilities',
    'VEEV': 'Health Care',
    'NTR': 'Materials',
    'CCEP': 'Consumer Staples',
    'BCS': 'Financials',
    'RYAAY': 'Industrials',
    'AEM': 'Materials',
    'EC': 'Energy',
    'ARGX': 'Health Care',
    'TU': 'Communication Services',
    'SPLK': 'Information Technology',
    'WIT': 'Information Technology',
    'DB': 'Financials',
    'HUBS': 'Information Technology',
    'VOD': 'Communication Services',
    'TEF': 'Communication Services',
    'TLK': 'Communication Services',
    'NWG': 'Financials',
    'GIB': 'Information Technology',
    'DFS': 'Financials',
    'TCOM': 'Consumer Discretionary',
    'RCI': 'Communication Services',
    'WPM': 'Materials',
    'FNV': 'Materials',
    'ICLR': 'Health Care',
    'SE': 'Consumer Discretionary',
    'SNAP': 'Communication Services',
    'IX': 'Financials',
    'FCNCA': 'Financials',
    'MT': 'Materials',
    'HEI': 'Industrials',
    'GMAB': 'Health Care',
    'ALNY': 'Health Care',
    'BGNE': 'Health Care',
    'UMC': 'Information Technology',
    'TS': 'Energy',
    'NOK': 'Information Technology',
    'FTS': 'Utilities',
    'CCJ': 'Materials',
    'PDX': 'Health Care',
    'TW': 'Information Technology',
    'ALC': 'Health Care',
    'PINS': 'Communication Services',
    'ZM': 'Information Technology',
    'NET': 'Information Technology',
    'DDOG': 'Information Technology',
    'BNTX': 'Health Care',
    'LI': 'Consumer Discretionary',
    'BEKE': 'Real Estate',
    'SNOW': 'Information Technology',
    'SYM': 'Information Technology',
    'RBLX': 'Communication Services',
    'CPNG': 'Consumer Discretionary',
    'GFS': 'Information Technology',
    'NU': 'Financials',
    'HLN': 'Health Care',
    'MBLY': 'Information Technology',
    'ARM': 'Information Technology',
    'HES': 'Energy',
    'ANSS':'Information Technology'
}

# %%
merged_df['Sector'] = merged_df['Sector'].fillna(merged_df['Company'].map(company_sector_map))

# %%
merged_df[merged_df[['Company', 'Sector']].isna().any(axis=1)].nunique()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Company         0
# Sector          0
# Industry        0
# dtype: int64

# %%
# count how many companies in each sector after dealing with NaN value 
filter = merged_df.groupby('Sector')['Company'].transform(lambda x: x.isna().any())
merged_df[filter]
# result : graceful
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Dividends, Stock Splits, Company, Sector, Industry]
# Index: []

# %%
# drop duplicates so we have the unique value to count on 
unique_company_industries = merged_df[['Company', 'Industry']].drop_duplicates()
unique_company_industries.count()
# Out:
# Company     491
# Industry    334
# dtype: int64

# %%
# count total companies that belongs to industries
# sub-category of Sector
industry_company_counts = unique_company_industries['Industry'].value_counts()
industry_company_counts
# Out:
# Industry
# Health Care Equipment            13
# Electric Utilities               12
# Semiconductors                   12
# Application Software             11
# Aerospace & Defense               9
#                                  ..
# Food Distributors                 1
# Casinos & Gaming                  1
# Advertising                       1
# Food Retail                       1
# Specialized Consumer Services     1
# Name: count, Length: 110, dtype: int64

# %%
# check for NaN values once again
merged_df[merged_df['Sector'].isna()].drop_duplicates('Company')
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Dividends, Stock Splits, Company, Sector, Industry]
# Index: []

# %%
merged_df.to_csv('stock_market_5yrs_final.csv')

# %%
# run the cell when you need to compress the final .csv file :)
merged_df.to_csv('stock_market_5yrs_final2.csv.bz2', compression='bz2')

# %% [markdown]
# ### Research 1 :
#     1) Which industry sectors exhibit the strongest correlations in their stock price returns?

# %%
merged_df
# Out:
#                              Date        Open        High         Low  \
# 0       2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594
# 1       2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595
# 2       2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998
# 3       2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501
# 4       2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195
# ...                           ...         ...         ...         ...
# 602957  2023-11-29 00:00:00-05:00   26.360001   26.397499   26.120001
# 602958  2023-11-29 00:00:00-05:00   27.680000   28.535000   27.680000
# 602959  2023-11-29 00:00:00-05:00   75.940002   76.555000   75.257500
# 602960  2023-11-29 00:00:00-05:00   45.230000   45.259998   44.040001
# 602961  2023-11-29 00:00:00-05:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company  \
# 0        43.083508  167080000       0.00           0.0    AAPL
# 1       104.636131   28123200       0.00           0.0    MSFT
# 2        54.729000   31004000       0.00           0.0   GOOGL
# 3        83.678497  132264000       0.00           0.0    AMZN
# 4        39.037853   54917200       0.04           0.0    NVDA
# ...            ...        ...        ...           ...     ...
# 602957   26.150000    1729147       0.00           0.0     PPL
# 602958   28.350000    1940066       0.00           0.0    FITB
# 602959   75.610001     298699       0.00           0.0     IFF
# 602960   44.209999    2217579       0.00           0.0     CCJ
# 602961   83.889999     830092       0.00           0.0     LYV
#
#                         Sector                                    Industry
# 0       Information Technology  Technology Hardware, Storage & Peripherals
# 1       Information Technology                            Systems Software
# 2       Communication Services                Interactive Media & Services
# 3       Consumer Discretionary                            Broadline Retail
# 4       Information Technology                              Semiconductors
# ...                        ...                                         ...
# 602957               Utilities                          Electric Utilities
# 602958              Financials                              Regional Banks
# 602959               Materials                         Specialty Chemicals
# 602960               Materials                                         NaN
# 602961  Communication Services                      Movies & Entertainment
#
# [602962 rows x 11 columns]

# %%
# data prep 
merged_df['Date'] = pd.to_datetime(merged_df['Date'],  utc=True)
merged_df = merged_df.sort_values(by='Date')
merged_df
# Out:
#                             Date        Open        High         Low  \
# 0      2018-11-29 05:00:00+00:00   43.829761   43.863354   42.639594
# 312    2018-11-29 05:00:00+00:00   75.903743   76.029017   75.142496
# 311    2018-11-29 05:00:00+00:00   56.789875   56.789875   56.789875
# 310    2018-11-29 05:00:00+00:00   37.257999   37.367001   36.585999
# 309    2018-11-29 05:00:00+00:00   13.439500   14.347000   13.439500
# ...                          ...         ...         ...         ...
# 602627 2023-11-29 05:00:00+00:00   91.220001   91.684998   90.919998
# 602626 2023-11-29 05:00:00+00:00  470.279999  471.410614  464.440002
# 602625 2023-11-29 05:00:00+00:00  274.600006  276.049988  274.390015
# 602623 2023-11-29 05:00:00+00:00   65.650002   65.970001   65.260002
# 602961 2023-11-29 05:00:00+00:00   84.629997   84.995003   83.529999
#
#              Close     Volume  Dividends  Stock Splits Company  \
# 0        43.083508  167080000        0.0           0.0    AAPL
# 312      75.450851     466800        0.0           0.0     WCN
# 311      56.789875        300        0.0           0.0    FERG
# 310      37.042999    1853000        0.0           0.0    CSGP
# 309      14.081000   15479000        0.0           0.0     TTD
# ...            ...        ...        ...           ...     ...
# 602627   90.980003     962390        0.0           0.0     DUK
# 602626  467.255005     222279        0.0           0.0     NOC
# 602625  275.635010     299304        0.0           0.0     SHW
# 602623   65.709999    1184237        0.0           0.0     CNQ
# 602961   83.889999     830092        0.0           0.0     LYV
#
#                         Sector                                    Industry
# 0       Information Technology  Technology Hardware, Storage & Peripherals
# 312                Industrials                                         NaN
# 311                Industrials                                         NaN
# 310                Real Estate                        Real Estate Services
# 309     Communication Services                                 Advertising
# ...                        ...                                         ...
# 602627               Utilities                          Electric Utilities
# 602626             Industrials                         Aerospace & Defense
# 602625               Materials                         Specialty Chemicals
# 602623                  Energy                                         NaN
# 602961  Communication Services                      Movies & Entertainment
#
# [602962 rows x 11 columns]

# %%
# calculate daily average close price per sector
sector_daily = merged_df.groupby(['Date', 'Sector'])['Close'].mean().unstack()
sector_daily
# Out:
# Sector                     Communication Services  Consumer Discretionary  \
# Date
# 2018-11-29 05:00:00+00:00               74.497502              211.353656
# 2018-11-30 05:00:00+00:00               74.368421              211.014481
# 2018-12-03 05:00:00+00:00               74.424215              215.803014
# 2018-12-04 05:00:00+00:00               72.300619              210.566665
# 2018-12-06 05:00:00+00:00               73.433396              212.042014
# ...                                           ...                     ...
# 2023-11-22 05:00:00+00:00              101.625407              465.726734
# 2023-11-24 05:00:00+00:00              101.793241              465.765669
# 2023-11-27 05:00:00+00:00              101.354287              464.557106
# 2023-11-28 05:00:00+00:00              101.367500              464.368664
# 2023-11-29 05:00:00+00:00              100.880492              464.405456
#
# Sector                     Consumer Staples     Energy  Financials  \
# Date
# 2018-11-29 05:00:00+00:00         72.924028  38.097533   68.842561
# 2018-11-30 05:00:00+00:00         73.043186  37.893428   69.344613
# 2018-12-03 05:00:00+00:00         73.327370  38.888907   69.849183
# 2018-12-04 05:00:00+00:00         71.692393  37.752970   67.134202
# 2018-12-06 05:00:00+00:00         71.835958  37.025996   66.600321
# ...                                     ...        ...         ...
# 2023-11-22 05:00:00+00:00        108.464839  66.634616  128.917785
# 2023-11-24 05:00:00+00:00        108.858387  67.025128  129.649069
# 2023-11-27 05:00:00+00:00        108.563228  66.735897  129.575329
# 2023-11-28 05:00:00+00:00        108.995161  66.891282  129.086219
# 2023-11-29 05:00:00+00:00        108.406177  66.791236  130.382750
#
# Sector                     Health Care  Industrials  Information Technology  \
# Date
# 2018-11-29 05:00:00+00:00   127.046782   102.267397               79.357215
# 2018-11-30 05:00:00+00:00   128.289446   103.219757               80.870292
# 2018-12-03 05:00:00+00:00   129.763276   104.187298               82.322963
# 2018-12-04 05:00:00+00:00   126.371246    99.773947               79.124210
# 2018-12-06 05:00:00+00:00   125.493871    99.068023               79.677697
# ...                                ...          ...                     ...
# 2023-11-22 05:00:00+00:00   220.715499   199.326229              220.817838
# 2023-11-24 05:00:00+00:00   221.900583   199.926557              221.331217
# 2023-11-27 05:00:00+00:00   220.600834   199.089673              221.080676
# 2023-11-28 05:00:00+00:00   218.933168   197.467213              220.817703
# 2023-11-29 05:00:00+00:00   219.496057   198.351569              224.856479
#
# Sector                      Materials  Real Estate  Utilities
# Date
# 2018-11-29 05:00:00+00:00   65.197668    98.006036  48.500304
# 2018-11-30 05:00:00+00:00   65.240877    98.839835  49.262464
# 2018-12-03 05:00:00+00:00   66.210187    99.301056  49.674294
# 2018-12-04 05:00:00+00:00   64.528853    98.192822  49.797422
# 2018-12-06 05:00:00+00:00   64.129063   100.525710  49.806807
# ...                               ...          ...        ...
# 2023-11-22 05:00:00+00:00  116.410019   143.339999  67.088334
# 2023-11-24 05:00:00+00:00  116.517856   143.792106  67.357916
# 2023-11-27 05:00:00+00:00  116.505357   144.321578  67.390000
# 2023-11-28 05:00:00+00:00  116.547858   144.916841  67.573333
# 2023-11-29 05:00:00+00:00  116.787061   146.393510  67.172504
#
# [1258 rows x 11 columns]

# %%
# compute daily percentage returns
sector_returns = sector_daily.pct_change().dropna()
sector_returns
# Out:
# Sector                     Communication Services  Consumer Discretionary  \
# Date
# 2018-11-30 05:00:00+00:00               -0.001733               -0.001605
# 2018-12-03 05:00:00+00:00                0.000750                0.022693
# 2018-12-04 05:00:00+00:00               -0.028534               -0.024264
# 2018-12-06 05:00:00+00:00                0.015668                0.007007
# 2018-12-07 05:00:00+00:00               -0.025087               -0.023164
# ...                                           ...                     ...
# 2023-11-22 05:00:00+00:00                0.009068                0.001777
# 2023-11-24 05:00:00+00:00                0.001652                0.000084
# 2023-11-27 05:00:00+00:00               -0.004312               -0.002595
# 2023-11-28 05:00:00+00:00                0.000130               -0.000406
# 2023-11-29 05:00:00+00:00               -0.004804                0.000079
#
# Sector                     Consumer Staples    Energy  Financials  \
# Date
# 2018-11-30 05:00:00+00:00          0.001634 -0.005357    0.007293
# 2018-12-03 05:00:00+00:00          0.003891  0.026270    0.007276
# 2018-12-04 05:00:00+00:00         -0.022297 -0.029210   -0.038869
# 2018-12-06 05:00:00+00:00          0.002003 -0.019256   -0.007952
# 2018-12-07 05:00:00+00:00         -0.016823 -0.001987   -0.017698
# ...                                     ...       ...         ...
# 2023-11-22 05:00:00+00:00          0.008174 -0.002097    0.002767
# 2023-11-24 05:00:00+00:00          0.003628  0.005861    0.005672
# 2023-11-27 05:00:00+00:00         -0.002711 -0.004315   -0.000569
# 2023-11-28 05:00:00+00:00          0.003979  0.002328   -0.003775
# 2023-11-29 05:00:00+00:00         -0.005404 -0.001496    0.010044
#
# Sector                     Health Care  Industrials  Information Technology  \
# Date
# 2018-11-30 05:00:00+00:00     0.009781     0.009312                0.019067
# 2018-12-03 05:00:00+00:00     0.011488     0.009374                0.017963
# 2018-12-04 05:00:00+00:00    -0.026140    -0.042360               -0.038856
# 2018-12-06 05:00:00+00:00    -0.006943    -0.007075                0.006995
# 2018-12-07 05:00:00+00:00    -0.043520    -0.024830               -0.037291
# ...                                ...          ...                     ...
# 2023-11-22 05:00:00+00:00     0.004673     0.001320                0.001877
# 2023-11-24 05:00:00+00:00     0.005369     0.003012                0.002325
# 2023-11-27 05:00:00+00:00    -0.005857    -0.004186               -0.001132
# 2023-11-28 05:00:00+00:00    -0.007560    -0.008149               -0.001189
# 2023-11-29 05:00:00+00:00     0.002571     0.004478                0.018290
#
# Sector                     Materials  Real Estate  Utilities
# Date
# 2018-11-30 05:00:00+00:00   0.000663     0.008508   0.015715
# 2018-12-03 05:00:00+00:00   0.014857     0.004666   0.008360
# 2018-12-04 05:00:00+00:00  -0.025394    -0.011160   0.002479
# 2018-12-06 05:00:00+00:00  -0.006196     0.023758   0.000188
# 2018-12-07 05:00:00+00:00  -0.018384    -0.014614   0.004477
# ...                              ...          ...        ...
# 2023-11-22 05:00:00+00:00   0.001976     0.002817   0.004102
# 2023-11-24 05:00:00+00:00   0.000926     0.003154   0.004018
# 2023-11-27 05:00:00+00:00  -0.000107     0.003682   0.000476
# 2023-11-28 05:00:00+00:00   0.000365     0.004125   0.002720
# 2023-11-29 05:00:00+00:00   0.002052     0.010190  -0.005932
#
# [1257 rows x 11 columns]

# %%
# sector returns
plt.figure(figsize=(14, 8))

for sector in sector_returns.columns:
    plt.plot(sector_returns.index, sector_returns[sector], label=sector)

plt.title('Daily Percentage Returns by Sector')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.legend()
plt.show()

# %%
# sector daily
plt.figure(figsize=(14, 8))

for sector in sector_daily.columns:
    plt.plot(sector_daily.index, sector_daily[sector], label=sector)

plt.title('Daily Returns by Sector')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.legend()
plt.show()

# %%
from scipy.stats import kstest, norm

ks_results = {}

for sector in sector_returns.columns:
    data = sector_returns[sector].dropna()
    # standardize data to mean=0, std=1 for KS test
    standardized_data = (data - data.mean()) / data.std()
    
    ks_stat, ks_p = kstest(standardized_data, 'norm')
    
    pass_fail = 'Pass' if ks_p >= 0.05 else 'Fail' # significance level = 0.05    
    ks_results[sector] = {'KS statistic': ks_stat, 'p-value': ks_p}

ks_df_q1 = pd.DataFrame(ks_results).T
ks_df_q1
# Out:
#                         KS statistic       p-value
# Communication Services      0.063233  8.205209e-05
# Consumer Discretionary      0.088780  4.530116e-09
# Consumer Staples            0.089062  3.989900e-09
# Energy                      0.069605  9.691812e-06
# Financials                  0.096191  1.418306e-10
# Health Care                 0.065380  4.087780e-05
# Industrials                 0.088413  5.339672e-09
# Information Technology      0.060806  1.753852e-04
# Materials                   0.072692  3.197569e-06
# Real Estate                 0.067798  1.813657e-05
# Utilities                   0.090355  2.221036e-09

# %%
# check whether normality pass/fail
for sector in sector_returns.columns:
    ks_results[sector] = pass_fail
ks_results
# Out:
# {'Communication Services': 'Fail',
#  'Consumer Discretionary': 'Fail',
#  'Consumer Staples': 'Fail',
#  'Energy': 'Fail',
#  'Financials': 'Fail',
#  'Health Care': 'Fail',
#  'Industrials': 'Fail',
#  'Information Technology': 'Fail',
#  'Materials': 'Fail',
#  'Real Estate': 'Fail',
#  'Utilities': 'Fail'}

# %%
# non-parametric test method : Spearman
correlation_matrix_2 = sector_returns.corr(method='spearman')
sns.heatmap(correlation_matrix_2, annot=True, cmap='plasma', center=0, linewidths=0.5)
plt.title('Correlation Heatmap of Sector Movements (Based on Daily Returns)')
plt.figure(figsize=(20, 20))
plt.show()

# %%
# spearman's method
sector_pairs = []
sectors = correlation_matrix_2.columns

for i in range(len(sectors)):
    for j in range(i + 1, len(sectors)):
        sector1 = sectors[i]
        sector2 = sectors[j]
        corr = correlation_matrix_2.loc[sector1, sector2]
        if pd.notna(corr):
            sector_pairs.append({
                'Sector 1': sector1,
                'Sector 2': sector2,
                'Correlation': corr
            })

pairwise_df_2 = pd.DataFrame(sector_pairs)

# sort by correlation
top_10_2 = pairwise_df_2.sort_values(by='Correlation', ascending=False).head(10)
bottom_10_2 = pairwise_df_2.sort_values(by='Correlation', ascending=True).head(10)

print("10 Most Correlated Sector Pairs:\n")
print(top_10_2.to_string(index=False))

print("\n10 Least Correlated Sector Pairs:\n")
print(bottom_10_2.to_string(index=False))
# Out:
# 10 Most Correlated Sector Pairs:
#
#               Sector 1               Sector 2  Correlation
#             Financials            Industrials     0.852745
#            Industrials              Materials     0.833247
#             Financials              Materials     0.793747
# Communication Services Information Technology     0.791829
# Consumer Discretionary Information Technology     0.743207
# Consumer Discretionary             Financials     0.736142
# Consumer Discretionary            Industrials     0.721649
#            Health Care Information Technology     0.704721
# Consumer Discretionary              Materials     0.694810
#             Financials Information Technology     0.686494
#
# 10 Least Correlated Sector Pairs:
#
#               Sector 1               Sector 2  Correlation
#                 Energy            Real Estate     0.214914
#                 Energy              Utilities     0.222615
# Communication Services              Utilities     0.251555
# Information Technology              Utilities     0.256181
# Communication Services                 Energy     0.306768
#                 Energy Information Technology     0.329320
#                 Energy            Health Care     0.336504
#       Consumer Staples                 Energy     0.347171
# Consumer Discretionary              Utilities     0.364045
# Consumer Discretionary                 Energy     0.405307

# %%
sns.clustermap(correlation_matrix_2, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap of Sector Movements (Based on Daily Returns)')
plt.savefig("../results/figures/correlation_heatmap.png")

# %%
sectors = sector_returns.columns.tolist()
sectors
# Out:
# ['Communication Services',
#  'Consumer Discretionary',
#  'Consumer Staples',
#  'Energy',
#  'Financials',
#  'Health Care',
#  'Industrials',
#  'Information Technology',
#  'Materials',
#  'Real Estate',
#  'Utilities']

# %%
from scipy.stats import spearmanr

results = []

for i in range(len(sectors)):
    for j in range(i + 1, len(sectors)):
        s1 = sector_returns[sectors[i]]
        s2 = sector_returns[sectors[j]]
        
        coef, p = spearmanr(s1, s2)
        
        reject_null = "YES" if p < 0.05 else "NO"
        
        results.append({
            'Sector 1': sectors[i],
            'Sector 2': sectors[j],
            'Spearman Coefficient': coef,
            'P-value': p,
            'Reject Null?': reject_null
        })

results_df = pd.DataFrame(results)

# sort by strongest correlation
results_df.sort_values(by='Spearman Coefficient', ascending=False)
# Out:
#                   Sector 1                Sector 2  Spearman Coefficient  \
# 35              Financials             Industrials              0.852745
# 46             Industrials               Materials              0.833247
# 37              Financials               Materials              0.793747
# 6   Communication Services  Information Technology              0.791829
# 15  Consumer Discretionary  Information Technology              0.743207
# 12  Consumer Discretionary              Financials              0.736142
# 14  Consumer Discretionary             Industrials              0.721649
# 41             Health Care  Information Technology              0.704721
# 16  Consumer Discretionary               Materials              0.694810
# 36              Financials  Information Technology              0.686494
# 0   Communication Services  Consumer Discretionary              0.686430
# 22        Consumer Staples             Industrials              0.684010
# 20        Consumer Staples              Financials              0.673982
# 34              Financials             Health Care              0.665970
# 24        Consumer Staples               Materials              0.650155
# 54             Real Estate               Utilities              0.644293
# 40             Health Care             Industrials              0.639713
# 3   Communication Services              Financials              0.637155
# 10  Consumer Discretionary        Consumer Staples              0.635796
# 45             Industrials  Information Technology              0.631710
# 21        Consumer Staples             Health Care              0.631436
# 13  Consumer Discretionary             Health Care              0.625318
# 4   Communication Services             Health Care              0.624488
# 26        Consumer Staples               Utilities              0.623543
# 25        Consumer Staples             Real Estate              0.622428
# 42             Health Care               Materials              0.620500
# 49  Information Technology               Materials              0.606220
# 43             Health Care             Real Estate              0.604491
# 29                  Energy             Industrials              0.591339
# 27                  Energy              Financials              0.579995
# 31                  Energy               Materials              0.564217
# 7   Communication Services               Materials              0.556007
# 38              Financials             Real Estate              0.553402
# 47             Industrials             Real Estate              0.545576
# 5   Communication Services             Industrials              0.544957
# 17  Consumer Discretionary             Real Estate              0.542348
# 50  Information Technology             Real Estate              0.536216
# 52               Materials             Real Estate              0.528011
# 23        Consumer Staples  Information Technology              0.527485
# 1   Communication Services        Consumer Staples              0.512067
# 8   Communication Services             Real Estate              0.500162
# 48             Industrials               Utilities              0.472141
# 44             Health Care               Utilities              0.452715
# 39              Financials               Utilities              0.442612
# 53               Materials               Utilities              0.436240
# 11  Consumer Discretionary                  Energy              0.405307
# 18  Consumer Discretionary               Utilities              0.364045
# 19        Consumer Staples                  Energy              0.347171
# 28                  Energy             Health Care              0.336504
# 30                  Energy  Information Technology              0.329320
# 2   Communication Services                  Energy              0.306768
# 51  Information Technology               Utilities              0.256181
# 9   Communication Services               Utilities              0.251555
# 33                  Energy               Utilities              0.222615
# 32                  Energy             Real Estate              0.214914
#
#           P-value Reject Null?
# 35   0.000000e+00          YES
# 46   0.000000e+00          YES
# 37  2.974648e-273          YES
# 6   5.084228e-271          YES
# 15  2.762409e-221          YES
# 12  5.427919e-215          YES
# 14  1.074613e-202          YES
# 41  2.739592e-189          YES
# 16  7.100593e-182          YES
# 36  6.959043e-176          YES
# 0   7.727964e-176          YES
# 22  3.923034e-174          YES
# 20  3.060963e-167          YES
# 34  6.310755e-162          YES
# 24  6.575226e-152          YES
# 54  2.401719e-148          YES
# 40  1.287618e-145          YES
# 3   4.115210e-144          YES
# 10  2.554476e-143          YES
# 45  5.879045e-141          YES
# 21  8.438214e-141          YES
# 13  2.473874e-137          YES
# 4   7.201803e-137          YES
# 26  2.424862e-136          YES
# 25  1.008797e-135          YES
# 42  1.173966e-134          YES
# 49  5.415004e-127          YES
# 43  4.318874e-126          YES
# 29  2.073564e-119          YES
# 27  6.870970e-114          YES
# 31  1.458372e-106          YES
# 7   6.641241e-103          YES
# 38  9.162601e-102          YES
# 47   2.118173e-98          YES
# 5    3.873836e-98          YES
# 17   4.873995e-97          YES
# 50   1.715295e-94          YES
# 52   3.634411e-91          YES
# 23   5.899277e-91          YES
# 1    5.876836e-85          YES
# 8    1.565375e-80          YES
# 48   8.823922e-71          YES
# 44   1.558078e-64          YES
# 39   1.929449e-61          YES
# 53   1.524091e-59          YES
# 11   6.891212e-51          YES
# 18   1.107072e-40          YES
# 19   6.439452e-37          YES
# 28   1.182411e-34          YES
# 30   3.531620e-33          YES
# 2    8.479695e-29          YES
# 51   2.755049e-20          YES
# 9    1.355466e-19          YES
# 33   1.403094e-15          YES
# 32   1.337544e-14          YES

# %% [markdown]
# #### EDA
#     the highest correlation : financials and Industrials
#     the lowest correlation : Energy and Real Estate

# %% [markdown]
# #### Inferential Methods
#     test : Spearman correlation test
#     method :  compare pairwise sector correlation

# %% [markdown]
# #### Inferential analysis
#     null hypothesis : There is no correlation between sector returns
#     alternative hypothesis : There is a significant correlation between sector returns

# %% [markdown]
# ### Research 2 :
#     2) How did different sectors perform during key COVID-19 periods (pre-pandemic, pandemic onset, and recovery)?

# %%
# CUMULATIVE RETURN

# calculate daily sector average close prices
# group and unstack (make sure 'Date' becomes index)
# set index as datetime 
sector_daily.index = pd.to_datetime(sector_daily.index)

pre_covid = sector_daily.loc['2019-01-01':'2020-02-29']
during_covid = sector_daily.loc['2020-03-01':'2020-06-30'] # covid started on March, 2020. 
post_covid = sector_daily.loc['2020-07-01':'2021-12-31']

def get_cumulative_return(df):# pass in dataframe
    return (df / df.iloc[0] - 1).iloc[-1] * 100  # percent return

pre_returns = get_cumulative_return(pre_covid)
during_returns = get_cumulative_return(during_covid)
post_returns = get_cumulative_return(post_covid)

# combine dataframe 
cumulative_returns = pd.DataFrame({
    'Pre-COVID': pre_returns,
    'During COVID': during_returns,
    'Post-COVID': post_returns
}).sort_values('During COVID', ascending=True) 

cumulative_returns.plot(kind='barh', figsize=(12, 10), colormap='Accent') # showing in horizontal bar chart
plt.title("Sector Performance During COVID-19 Periods")
plt.xlabel("Cumulative Return (%)")
plt.ylabel("Sector")
plt.grid(True)
plt.tight_layout()
plt.show()
plt.savefig("../results/figures/sector_performance_during_covid19.png")

# %%
sector_returns
# Out:
# Sector                     Communication Services  Consumer Discretionary  \
# Date
# 2018-11-30 05:00:00+00:00               -0.001733               -0.001605
# 2018-12-03 05:00:00+00:00                0.000750                0.022693
# 2018-12-04 05:00:00+00:00               -0.028534               -0.024264
# 2018-12-06 05:00:00+00:00                0.015668                0.007007
# 2018-12-07 05:00:00+00:00               -0.025087               -0.023164
# ...                                           ...                     ...
# 2023-11-22 05:00:00+00:00                0.009068                0.001777
# 2023-11-24 05:00:00+00:00                0.001652                0.000084
# 2023-11-27 05:00:00+00:00               -0.004312               -0.002595
# 2023-11-28 05:00:00+00:00                0.000130               -0.000406
# 2023-11-29 05:00:00+00:00               -0.004804                0.000079
#
# Sector                     Consumer Staples    Energy  Financials  \
# Date
# 2018-11-30 05:00:00+00:00          0.001634 -0.005357    0.007293
# 2018-12-03 05:00:00+00:00          0.003891  0.026270    0.007276
# 2018-12-04 05:00:00+00:00         -0.022297 -0.029210   -0.038869
# 2018-12-06 05:00:00+00:00          0.002003 -0.019256   -0.007952
# 2018-12-07 05:00:00+00:00         -0.016823 -0.001987   -0.017698
# ...                                     ...       ...         ...
# 2023-11-22 05:00:00+00:00          0.008174 -0.002097    0.002767
# 2023-11-24 05:00:00+00:00          0.003628  0.005861    0.005672
# 2023-11-27 05:00:00+00:00         -0.002711 -0.004315   -0.000569
# 2023-11-28 05:00:00+00:00          0.003979  0.002328   -0.003775
# 2023-11-29 05:00:00+00:00         -0.005404 -0.001496    0.010044
#
# Sector                     Health Care  Industrials  Information Technology  \
# Date
# 2018-11-30 05:00:00+00:00     0.009781     0.009312                0.019067
# 2018-12-03 05:00:00+00:00     0.011488     0.009374                0.017963
# 2018-12-04 05:00:00+00:00    -0.026140    -0.042360               -0.038856
# 2018-12-06 05:00:00+00:00    -0.006943    -0.007075                0.006995
# 2018-12-07 05:00:00+00:00    -0.043520    -0.024830               -0.037291
# ...                                ...          ...                     ...
# 2023-11-22 05:00:00+00:00     0.004673     0.001320                0.001877
# 2023-11-24 05:00:00+00:00     0.005369     0.003012                0.002325
# 2023-11-27 05:00:00+00:00    -0.005857    -0.004186               -0.001132
# 2023-11-28 05:00:00+00:00    -0.007560    -0.008149               -0.001189
# 2023-11-29 05:00:00+00:00     0.002571     0.004478                0.018290
#
# Sector                     Materials  Real Estate  Utilities
# Date
# 2018-11-30 05:00:00+00:00   0.000663     0.008508   0.015715
# 2018-12-03 05:00:00+00:00   0.014857     0.004666   0.008360
# 2018-12-04 05:00:00+00:00  -0.025394    -0.011160   0.002479
# 2018-12-06 05:00:00+00:00  -0.006196     0.023758   0.000188
# 2018-12-07 05:00:00+00:00  -0.018384    -0.014614   0.004477
# ...                              ...          ...        ...
# 2023-11-22 05:00:00+00:00   0.001976     0.002817   0.004102
# 2023-11-24 05:00:00+00:00   0.000926     0.003154   0.004018
# 2023-11-27 05:00:00+00:00  -0.000107     0.003682   0.000476
# 2023-11-28 05:00:00+00:00   0.000365     0.004125   0.002720
# 2023-11-29 05:00:00+00:00   0.002052     0.010190  -0.005932
#
# [1257 rows x 11 columns]

# %%
for sector in sector_returns.columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(sector_returns[sector], bins=50, kde=True, color='skyblue')
    plt.title(f'Distribution of Daily Returns: {sector}')
    plt.xlabel('Daily Return')
    plt.ylabel('Frequency')
    plt.show()
    plt.savefig(f"../results/figures/distribution_of_daily_returns/{sector}.png", dpi=300, bbox_inches='tight')

# %%
from scipy.stats import shapiro

for sector in sector_returns.columns:
    data = sector_returns[sector].dropna()
    stat, p_value = shapiro(data) 
    print(f'{sector}: p-value = {p_value:.4f}')
    if p_value < 0.05:
        print("Not normally distributed\n")
    else:
        print("Looks normal\n")
# even if the plot above looks normally distributed but the test indicates that its not normally distributed
# Out:
# Communication Services: p-value = 0.0000
# Not normally distributed
#
# Consumer Discretionary: p-value = 0.0000
# Not normally distributed
#
# Consumer Staples: p-value = 0.0000
# Not normally distributed
#
# Energy: p-value = 0.0000
# Not normally distributed
#
# Financials: p-value = 0.0000
# Not normally distributed
#
# Health Care: p-value = 0.0000
# Not normally distributed
#
# Industrials: p-value = 0.0000
# Not normally distributed
#
# Information Technology: p-value = 0.0000
# Not normally distributed
#
# Materials: p-value = 0.0000
# Not normally distributed
#
# Real Estate: p-value = 0.0000
# Not normally distributed
#
# Utilities: p-value = 0.0000
# Not normally distributed

# %%
# COMPUTE USING DAILY RETURNS
from scipy.stats import kruskal

# periods
pre_covid_returns = sector_returns.loc['2019-01-01':'2020-02-29']
during_covid_returns = sector_returns.loc['2020-03-01':'2020-06-30']
post_covid_returns = sector_returns.loc['2020-07-01':'2021-12-31']


periods = {
    'Pre-COVID': pre_covid_returns,
    'During COVID': during_covid_returns,
    'Post-COVID': post_covid_returns
}

for sector in sector_returns.columns:
    # Collect returns of this sector for each period, dropping NaNs
    data = [periods[period][sector].dropna().values for period in periods]
    h_stat, p_value = kruskal(*data)
    
    print(f"Sector: {sector}")
    print()
    print(f"  Kruskal-Wallis H-statistic: {h_stat:.4f}, p-value: {p_value:.6f}")
    if p_value < 0.05:
        print("  --> Significant difference across periods\n") # reject null
    else:
        print("  --> No significant difference across periods\n") # cant reject null 
    print("===================================")
# Out:
# Sector: Communication Services
#
#   Kruskal-Wallis H-statistic: 3.7410, p-value: 0.154046
#   --> No significant difference across periods
#
# ===================================
# Sector: Consumer Discretionary
#
#   Kruskal-Wallis H-statistic: 0.9673, p-value: 0.616539
#   --> No significant difference across periods
#
# ===================================
# Sector: Consumer Staples
#
#   Kruskal-Wallis H-statistic: 0.3524, p-value: 0.838444
#   --> No significant difference across periods
#
# ===================================
# Sector: Energy
#
#   Kruskal-Wallis H-statistic: 0.8861, p-value: 0.642071
#   --> No significant difference across periods
#
# ===================================
# Sector: Financials
#
#   Kruskal-Wallis H-statistic: 0.4461, p-value: 0.800088
#   --> No significant difference across periods
#
# ===================================
# Sector: Health Care
#
#   Kruskal-Wallis H-statistic: 0.8152, p-value: 0.665251
#   --> No significant difference across periods
#
# ===================================
# Sector: Industrials
#
#   Kruskal-Wallis H-statistic: 0.1321, p-value: 0.936079
#   --> No significant difference across periods
#
# ===================================
# Sector: Information Technology
#
#   Kruskal-Wallis H-statistic: 1.9696, p-value: 0.373514
#   --> No significant difference across periods
#
# ===================================
# Sector: Materials
#
#   Kruskal-Wallis H-statistic: 3.3632, p-value: 0.186081
#   --> No significant difference across periods
#
# ===================================
# Sector: Real Estate
#
#   Kruskal-Wallis H-statistic: 0.1911, p-value: 0.908876
#   --> No significant difference across periods
#
# ===================================
# Sector: Utilities
#
#   Kruskal-Wallis H-statistic: 0.1233, p-value: 0.940232
#   --> No significant difference across periods
#
# ===================================

# %%
sector_returns = sector_returns.copy()
#sector_returns.index = pd.to_datetime(sector_returns.index)
sector_returns.index = sector_returns.index.tz_localize(None)

# Melt the data for easier plotting
sector_returns['Period'] = pd.cut(
    sector_returns.index,
    bins=[
        pd.to_datetime('2019-01-01'),
        pd.to_datetime('2020-02-29'),
        pd.to_datetime('2020-06-30'),
        pd.to_datetime('2021-12-31')
    ],
    labels=['Pre-COVID', 'During COVID', 'Post-COVID']
)


# Loop through sectors and plot
for sector in sector_returns.columns.drop('Period'):
    df_plot = sector_returns[[sector, 'Period']].dropna()
    df_plot = df_plot.rename(columns={sector: 'Daily Return'})
    
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
    plt.title(f'Daily Returns of {sector}')
    plt.axhline(0, color='gray', linestyle='--')
    plt.savefig(f"../results/figures/daily_returns_across_covid19_periods/{sector}.png")
    plt.show()
# Out:
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')
# C:\Users\thees\AppData\Local\Temp\ipykernel_44288\1519721159.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Period', y='Daily Return', data=df_plot, palette='Set1')

# %% [markdown]
# #### EDA
#     the outperformed sector: Information Technology
#     the underperformed sector: Energy
#         from the bar chart, every sector bounced back after COVID-19 situation, but the energy does not give a positive return after the COVID-19 situation. This circumstance might imply something significant about the sector.

# %% [markdown]
# #### Inferential Methods
#     test : Kruskal-Wallis test
#     method :  compare each sectors across 3 significant COVID-19 periods

# %% [markdown]
# #### Inferential analysis
#     null hypothesis : The sector’s daily return distributions are the same across the three periods (Pre-, During, and Post-COVID).
#     alternative hypothesis :  The sector’s return distribution differs in at least one period.

# %% [markdown]
# ### Research 3 :
#     3) Which industry sectors offer the best risk-adjusted returns over 5 years

# %%
merged_df = merged_df.sort_values(['Company', 'Date'])  # sort by company & date
merged_df
# Out:
#                             Date        Open        High         Low  \
# 285    2018-11-29 05:00:00+00:00   68.673458   69.589358   68.673458
# 743    2018-11-30 05:00:00+00:00   69.059076   70.042470   68.779483
# 1201   2018-12-03 05:00:00+00:00   70.698073   72.105671   70.563099
# 1659   2018-12-04 05:00:00+00:00   72.018907   72.414195   70.023203
# 2117   2018-12-06 05:00:00+00:00   68.644532   69.348335   67.391195
# ...                          ...         ...         ...         ...
# 600640 2023-11-22 05:00:00+00:00  180.000000  180.970001  178.779999
# 601131 2023-11-24 05:00:00+00:00  180.169998  181.389999  179.380005
# 601622 2023-11-27 05:00:00+00:00  180.029999  180.789993  178.470001
# 602113 2023-11-28 05:00:00+00:00  178.110001  178.360001  176.160004
# 602604 2023-11-29 05:00:00+00:00  177.869995  178.054993  175.240005
#
#              Close   Volume  Dividends  Stock Splits Company       Sector  \
# 285      69.001251  2625800        0.0           0.0       A  Health Care
# 743      69.753235  2279500        0.0           0.0       A  Health Care
# 1201     71.989975  4265200        0.0           0.0       A  Health Care
# 1659     70.293159  4263800        0.0           0.0       A  Health Care
# 2117     69.329056  3505900        0.0           0.0       A  Health Care
# ...            ...      ...        ...           ...     ...          ...
# 600640  179.350006  1501500        0.0           0.0     ZTS  Health Care
# 601131  180.210007   635200        0.0           0.0     ZTS  Health Care
# 601622  178.789993  1442700        0.0           0.0     ZTS  Health Care
# 602113  176.970001  1348900        0.0           0.0     ZTS  Health Care
# 602604  176.460007   537330        0.0           0.0     ZTS  Health Care
#
#                               Industry
# 285     Life Sciences Tools & Services
# 743     Life Sciences Tools & Services
# 1201    Life Sciences Tools & Services
# 1659    Life Sciences Tools & Services
# 2117    Life Sciences Tools & Services
# ...                                ...
# 600640                 Pharmaceuticals
# 601131                 Pharmaceuticals
# 601622                 Pharmaceuticals
# 602113                 Pharmaceuticals
# 602604                 Pharmaceuticals
#
# [602962 rows x 11 columns]

# %%
# Calculate daily returns per company
merged_df['Return'] = merged_df.groupby('Company')['Close'].pct_change()
merged_df
# Out:
#                             Date        Open        High         Low  \
# 285    2018-11-29 05:00:00+00:00   68.673458   69.589358   68.673458
# 743    2018-11-30 05:00:00+00:00   69.059076   70.042470   68.779483
# 1201   2018-12-03 05:00:00+00:00   70.698073   72.105671   70.563099
# 1659   2018-12-04 05:00:00+00:00   72.018907   72.414195   70.023203
# 2117   2018-12-06 05:00:00+00:00   68.644532   69.348335   67.391195
# ...                          ...         ...         ...         ...
# 600640 2023-11-22 05:00:00+00:00  180.000000  180.970001  178.779999
# 601131 2023-11-24 05:00:00+00:00  180.169998  181.389999  179.380005
# 601622 2023-11-27 05:00:00+00:00  180.029999  180.789993  178.470001
# 602113 2023-11-28 05:00:00+00:00  178.110001  178.360001  176.160004
# 602604 2023-11-29 05:00:00+00:00  177.869995  178.054993  175.240005
#
#              Close   Volume  Dividends  Stock Splits Company       Sector  \
# 285      69.001251  2625800        0.0           0.0       A  Health Care
# 743      69.753235  2279500        0.0           0.0       A  Health Care
# 1201     71.989975  4265200        0.0           0.0       A  Health Care
# 1659     70.293159  4263800        0.0           0.0       A  Health Care
# 2117     69.329056  3505900        0.0           0.0       A  Health Care
# ...            ...      ...        ...           ...     ...          ...
# 600640  179.350006  1501500        0.0           0.0     ZTS  Health Care
# 601131  180.210007   635200        0.0           0.0     ZTS  Health Care
# 601622  178.789993  1442700        0.0           0.0     ZTS  Health Care
# 602113  176.970001  1348900        0.0           0.0     ZTS  Health Care
# 602604  176.460007   537330        0.0           0.0     ZTS  Health Care
#
#                               Industry    Return
# 285     Life Sciences Tools & Services       NaN
# 743     Life Sciences Tools & Services  0.010898
# 1201    Life Sciences Tools & Services  0.032066
# 1659    Life Sciences Tools & Services -0.023570
# 2117    Life Sciences Tools & Services -0.013715
# ...                                ...       ...
# 600640                 Pharmaceuticals  0.003469
# 601131                 Pharmaceuticals  0.004795
# 601622                 Pharmaceuticals -0.007880
# 602113                 Pharmaceuticals -0.010179
# 602604                 Pharmaceuticals -0.002882
#
# [602962 rows x 12 columns]

# %%
# define 5-year period range based on max date in data
end_date = merged_df['Date'].max()
start_date = end_date - pd.DateOffset(years=5)

df_5yr = merged_df[(merged_df['Date'] >= start_date) & (merged_df['Date'] <= end_date)].copy() # filter
df_5yr = df_5yr.dropna(subset=['Return']) # drop rows missing values
df_5yr
# Out:
#                             Date        Open        High         Low  \
# 743    2018-11-30 05:00:00+00:00   69.059076   70.042470   68.779483
# 1201   2018-12-03 05:00:00+00:00   70.698073   72.105671   70.563099
# 1659   2018-12-04 05:00:00+00:00   72.018907   72.414195   70.023203
# 2117   2018-12-06 05:00:00+00:00   68.644532   69.348335   67.391195
# 2575   2018-12-07 05:00:00+00:00   69.136204   69.502563   67.150144
# ...                          ...         ...         ...         ...
# 600640 2023-11-22 05:00:00+00:00  180.000000  180.970001  178.779999
# 601131 2023-11-24 05:00:00+00:00  180.169998  181.389999  179.380005
# 601622 2023-11-27 05:00:00+00:00  180.029999  180.789993  178.470001
# 602113 2023-11-28 05:00:00+00:00  178.110001  178.360001  176.160004
# 602604 2023-11-29 05:00:00+00:00  177.869995  178.054993  175.240005
#
#              Close   Volume  Dividends  Stock Splits Company       Sector  \
# 743      69.753235  2279500        0.0           0.0       A  Health Care
# 1201     71.989975  4265200        0.0           0.0       A  Health Care
# 1659     70.293159  4263800        0.0           0.0       A  Health Care
# 2117     69.329056  3505900        0.0           0.0       A  Health Care
# 2575     67.728607  2184500        0.0           0.0       A  Health Care
# ...            ...      ...        ...           ...     ...          ...
# 600640  179.350006  1501500        0.0           0.0     ZTS  Health Care
# 601131  180.210007   635200        0.0           0.0     ZTS  Health Care
# 601622  178.789993  1442700        0.0           0.0     ZTS  Health Care
# 602113  176.970001  1348900        0.0           0.0     ZTS  Health Care
# 602604  176.460007   537330        0.0           0.0     ZTS  Health Care
#
#                               Industry    Return
# 743     Life Sciences Tools & Services  0.010898
# 1201    Life Sciences Tools & Services  0.032066
# 1659    Life Sciences Tools & Services -0.023570
# 2117    Life Sciences Tools & Services -0.013715
# 2575    Life Sciences Tools & Services -0.023085
# ...                                ...       ...
# 600640                 Pharmaceuticals  0.003469
# 601131                 Pharmaceuticals  0.004795
# 601622                 Pharmaceuticals -0.007880
# 602113                 Pharmaceuticals -0.010179
# 602604                 Pharmaceuticals -0.002882
#
# [602471 rows x 12 columns]

# %%
# group by Sector and Date, calculate mean daily return per sector
sector_returns_5yr = df_5yr.groupby(['Sector', 'Date'])['Return'].mean().reset_index()
sector_returns_5yr
# Out:
#                        Sector                      Date    Return
# 0      Communication Services 2018-11-30 05:00:00+00:00  0.001286
# 1      Communication Services 2018-12-03 05:00:00+00:00 -0.001537
# 2      Communication Services 2018-12-04 05:00:00+00:00 -0.022921
# 3      Communication Services 2018-12-06 05:00:00+00:00  0.010147
# 4      Communication Services 2018-12-07 05:00:00+00:00 -0.017152
# ...                       ...                       ...       ...
# 13822               Utilities 2023-11-22 05:00:00+00:00  0.003992
# 13823               Utilities 2023-11-24 05:00:00+00:00  0.003744
# 13824               Utilities 2023-11-27 05:00:00+00:00  0.000179
# 13825               Utilities 2023-11-28 05:00:00+00:00  0.002268
# 13826               Utilities 2023-11-29 05:00:00+00:00 -0.006043
#
# [13827 rows x 3 columns]

# %%
TRADING_DAYS = 252

# calculate annualized return, volatility, and Sharpe ratio for each sector
metrics = []

for sector, group in sector_returns_5yr.groupby('Sector'):
    daily_returns = group['Return']
    
    # annualized average return (geometric approx)
    avg_daily_return = daily_returns.mean()
    annualized_return = avg_daily_return * TRADING_DAYS
    
    # annualized volatility
    daily_volatility = daily_returns.std()
    annualized_volatility = daily_volatility * np.sqrt(TRADING_DAYS)
    
    # Sharpe ratio (assume risk-free rate = 0)
    sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan
    
    metrics.append({
        'Sector': sector,
        'Annualized Return': annualized_return,
        'Annualized Volatility': annualized_volatility,
        'Sharpe Ratio': sharpe_ratio
    })

metrics_df = pd.DataFrame(metrics)

# sort
metrics_df = metrics_df.sort_values(by='Sharpe Ratio', ascending=False).reset_index(drop=True)
print(metrics_df)
# Out:
#                     Sector  Annualized Return  Annualized Volatility  \
# 0   Information Technology           0.301698               0.297399
# 1              Health Care           0.181574               0.197282
# 2   Consumer Discretionary           0.216950               0.270998
# 3              Industrials           0.184231               0.231117
# 4                Materials           0.190384               0.245549
# 5         Consumer Staples           0.103422               0.170471
# 6   Communication Services           0.133441               0.226898
# 7               Financials           0.154039               0.264033
# 8                   Energy           0.207764               0.357886
# 9              Real Estate           0.135464               0.252306
# 10               Utilities           0.120147               0.226863
#
#     Sharpe Ratio
# 0       1.014457
# 1       0.920378
# 2       0.800558
# 3       0.797134
# 4       0.775341
# 5       0.606682
# 6       0.588113
# 7       0.583408
# 8       0.580531
# 9       0.536902
# 10      0.529603

# %%
# plot
plt.figure(figsize=(12,10))
plt.bar(metrics_df['Sector'], metrics_df['Sharpe Ratio'], color='skyblue',edgecolor = 'black')
plt.xticks(rotation=45, ha='right')
plt.title('Sector Sharpe Ratios (Last 5 Years)')
plt.ylabel('Sharpe Ratio')
plt.grid(axis='y', linestyle='--', alpha=0.8)
plt.tight_layout()
plt.show()
plt.savefig("../results/figures/sector_sharpe_ratios.png")

# %%
plt.figure(figsize=(10, 8))

# scatter: Expected Return vs Standard Deviation
plt.scatter(metrics_df['Annualized Volatility'], metrics_df['Annualized Return'],
            color='green', edgecolor='black')

# label each sector
for _, row in metrics_df.iterrows():
    plt.text(row['Annualized Volatility'], row['Annualized Return'], row['Sector'],
             fontsize=8, ha='right', va='bottom')

plt.title('Expected Return vs Risk by Sector (Last 5 Years)')
plt.xlabel('Annualized Volatility (Risk)')
plt.ylabel('Annualized Return (Expected Return)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig("../results/figures/sector_sharpe_ratios2.png")
plt.show()

# %%
bootstrap_samples = 1000
sharpe_by_sector = []

for sector in sectors:
    sector_returns = sector_returns_5yr.loc[
        sector_returns_5yr['Sector'] == sector, 'Return'
    ].values

    boot_sharpes = []
    for _ in range(bootstrap_samples):
        sample = np.random.choice(sector_returns, size=len(sector_returns), replace=True)
        mean = np.mean(sample) * TRADING_DAYS
        std = np.std(sample) * np.sqrt(TRADING_DAYS)
        sharpe = mean / std if std != 0 else np.nan
        boot_sharpes.append(sharpe)

    sharpe_by_sector.append(boot_sharpes)

h_stat, p_value = kruskal(*sharpe_by_sector)

print(f"Test used : Kruskal-Wallis")
print(f"H-statistic: {h_stat:.4f}")
print(f"P-value: {p_value:.6f}")

if p_value < 0.05:
    print("Reject H0: At least one industry sector has a Sharpe ratio that is significantly different from the other sectors")
else:
    print("Fail to reject H0: Aall sectors have the same Sharpe ratio")
# Out:
# Test used : Kruskal-Wallis
# H-statistic: 1162.5567
# P-value: 0.000000
# Reject H0: At least one industry sector has a Sharpe ratio that is significantly different from the other sectors

# %% [markdown]
# #### EDA
#     The industry sectors that offer the best risk-adjusted returns over 5 years is Information Technology
#     The industry sectors that offer the worst risk-adjusted returns over 5 years is Utilities

# %% [markdown]
# #### Inferential Methods
#     - test : Kruskal-Wallis

# %% [markdown]
# #### Inferential Analysis
#     - null hypothesis : all sectors have the same Sharpe ratio.
#     - alternative hypothesis : At least one industry sector has a Sharpe ratio that is significantly different
#     from the other sectors
